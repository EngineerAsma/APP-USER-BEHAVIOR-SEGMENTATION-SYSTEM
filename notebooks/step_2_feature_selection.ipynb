# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\User\\.vscode\\APP USER BEHAVIOR SEGMENTATION SYSTEM\\data\\cleaned_data.csv")

# %%
# step 4 : feature selection

selected_features = df.select_dtypes(include=['int64', 'float64'])

X = selected_features.drop(columns=['user_id', 'app_version'], axis=1)


print(type(X))
print(X.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    age  sessions_per_week  avg_session_duration_min  daily_active_minutes  \
# 0   56                  5                      3.41                 52.71
# 1   46                  8                     24.44                 42.03
# 2   32                 12                      5.34                 76.69
# 3   25                  5                      3.98                 65.38
# 4   38                 10                     12.85                 57.06
#
#    feature_clicks_per_session  notifications_opened_per_week  \
# 0                          13                              5
# 1                           7                              7
# 2                           7                              5
# 3                          16                              8
# 4                          13                              7
#
#    in_app_search_count  pages_viewed_per_session  crash_events_last_30_days  \
# ...

# %%
X.to_csv("C:\\Users\\User\\.vscode\\APP USER BEHAVIOR SEGMENTATION SYSTEM\\data\\selected_features.csv", index=False)
