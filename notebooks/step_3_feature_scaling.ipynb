# %%
import pandas as pd
X = pd.read_csv("C:\\Users\\User\\.vscode\\APP USER BEHAVIOR SEGMENTATION SYSTEM\\data\\selected_features.csv")

# %%
# step 5 : feature scaling

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# Convert back to DataFrame
X_scaled = pd.DataFrame(X_scaled, columns=X.columns)

# Preview scaled data
print(X_scaled.head())
print(X_scaled.describe())
# Out:
#         age  sessions_per_week  avg_session_duration_min  \
# 0  1.445821          -1.060179                 -1.088633
# 1  0.619022           0.000113                  1.261914
# 2 -0.538498           1.413835                 -0.872915
# 3 -1.117258          -1.060179                 -1.024924
# 4 -0.042418           0.706974                 -0.033514
#
#    daily_active_minutes  feature_clicks_per_session  \
# 0              0.386849                    0.283336
# 1             -0.160705                   -1.440677
# 2              1.616282                   -1.440677
# 3              1.036429                    1.145342
# 4              0.609870                    0.283336
#
#    notifications_opened_per_week  in_app_search_count  \
# 0                       0.001512             2.002730
# 1                       0.896304            -0.500094
# 2                       0.001512            -1.000659
# 3                       1.343700             0.000471
# ...

# %%
X_scaled.to_csv("C:\\Users\\User\\.vscode\\APP USER BEHAVIOR SEGMENTATION SYSTEM\\data\\scaled_features.csv", index=False)
